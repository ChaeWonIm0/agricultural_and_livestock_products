# %% [markdown]
# <a href="https://colab.research.google.com/github/dla9944/2019-2021_agricultural_and_livestock_products/blob/main/%EB%86%8D%EC%B6%95%EC%88%98%EC%82%B0%EB%AC%BC_%EA%B0%80%EA%B2%A9%EC%A0%95%EB%B3%B4_2019_2021_%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_6%EA%B0%9C%EC%A7%91%ED%95%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 로드

# %%
# 필요한 라이브러리 호출

# 기초
import numpy as np
import pandas as pd
# 시각화
import seaborn as sns
import matplotlib.pyplot as plt
from plotly import graph_objects as go
from plotly import express as px

# 사이킷런 분류
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV


# 스케일링
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler


from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV


# 지도학습

# 회귀 종류
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
# from xgboost import XGBRegressor
from lightgbm import LGBMRegressor


# 분류 종류
# from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import plot_tree



# 비지도학습
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# 경고메시지 무시
import warnings
warnings.filterwarnings(action='ignore') 
# 평가용
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import matplotlib.pyplot as plt
# 한글화 작업
plt.rc('font', family='NanumBarunGothic')

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %%
# # 잠깐 시각화
# plt.figure(figsize=(12,7))

# sns.countplot(data=df_19.head(6).sort_values(by = '품목 번호', ascending = True))

# %%
df_19 = pd.read_csv('C:/myPyCode/data/2021_물가/생필품 농수축산물 가격 정보(2019년).csv', encoding = 'cp949')
df_19
# Out:
#            일련번호  시장/마트 번호  시장/마트 이름  품목 번호        품목 이름      실판매규격  가격(원)  \
# 0       1496335       116  홈플러스 시흥점    311      오이(다다기)         1개   1190
# 1       1499702       115      남문시장    202   돼지고기(생삼겹살)  1등급(600g)  12500
# 2       1503366       115      남문시장    310     상추(100g)         1개    800
# 3       1499701       115      남문시장     58  쇠고기(한우,불고기)  1등급(600g)  23000
# 4       1503365       115      남문시장    309   양파(1.5kg망)         1개   2500
# ...         ...       ...       ...    ...          ...        ...    ...
# 113487  1359195       202      구로시장    312          애호박        1개    1500
# 113488  1357693        73      뚝도시장    306  배(신고, 600g)         1개   3900
# 113489  1359189       202      구로시장    306  배(신고, 600g)        1개    3500
# 113490  1357694        73      뚝도시장    307  배추(2.5~3kg)        1포기   2500
# 113491  1359188       202      구로시장     28           사과        1개    1250
#
#            년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 0       2019-12      국산                  2              대형마트  545000    금천구
# 1       2019-12      국산                  1              전통시장  545000    금천구
# 2       2019-12      국산                  1              전통시장  545000    금천구
# 3       2019-12      국산                  1              전통시장  545000    금천구
# 4       2019-12      국산                  1              전통시장  545000    금천구
# ...         ...     ...                ...               ...     ...    ...
# 113487  2019-01     국내산                  1              전통시장  530000    구로구
# 113488  2019-01     NaN                  1              전통시장  200000    성동구
# 113489  2019-01     국내산                  1              전통시장  530000    구로구
# 113490  2019-01     NaN                  1              전통시장  200000    성동구
# 113491  2019-01  4개5000                  1              전통시장  530000    구로구
#
#               점검일자
# 0       2019-12-30
# 1       2019-12-30
# 2       2019-12-30
# 3       2019-12-30
# 4       2019-12-30
# ...            ...
# 113487  2019-01-28
# 113488  2019-01-28
# 113489  2019-01-28
# 113490  2019-01-28
# 113491  2019-01-28
#
# [113492 rows x 14 columns]

# %%
df_21 = pd.read_csv('C:/myPyCode/data/2021_물가/생필품_농수축산물_가격_정보(2021년).csv', encoding = 'cp949')
df_21
# Out:
#           일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름      실판매규격  가격(원)  \
# 0      1636107       226  롯데마트 구로점     28          사과  1개 (300g)   1598
# 1      1636108       226  롯데마트 구로점     27           배  1개 (600g)   1590
# 2      1636109       226  롯데마트 구로점     26          배추   1포기(2kg)   3990
# 3      1636110       226  롯데마트 구로점     25           무  1개 (900g)   1990
# 4      1636111       226  롯데마트 구로점     24          양파  1개 (200g)    990
# ...        ...       ...       ...    ...         ...        ...    ...
# 89894  1724775       154  홈플러스 강동점    320     달걀(30개)         특란   6490
# 89895  1724776       154  홈플러스 강동점    144   조기(국산,냉동)        1마리   1190
# 89896  1724777       154  홈플러스 강동점    264  명태(냉동,수입산)        1마리   3490
# 89897  1724778       154  홈플러스 강동점    256  오징어(냉동,국산)        1마리   4980
# 89898  1724779       154  홈플러스 강동점    266  고등어(생물,국산)        1마리   3990
#
#           년도-월          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# 0      2021-01      국내산,부사                  2              대형마트  530000
# 1      2021-01      국내산,신고                  2              대형마트  530000
# 2      2021-01         국내산                  2              대형마트  530000
# 3      2021-01         국내산                  2              대형마트  530000
# 4      2021-01         국내산                  2              대형마트  530000
# ...        ...         ...                ...               ...     ...
# 89894  2021-12         국내산                  2              대형마트  740000
# 89895  2021-12  국내산3마리3570                  2              대형마트  740000
# 89896  2021-12    수입산(러시아)                  2              대형마트  740000
# 89897  2021-12         국내산                  2              대형마트  740000
# 89898  2021-12  국내산2마리7980                  2              대형마트  740000
#
#       자치구 이름        점검일자
# 0        구로구  2021-01-21
# 1        구로구  2021-01-21
# 2        구로구  2021-01-21
# 3        구로구  2021-01-21
# 4        구로구  2021-01-21
# ...      ...         ...
# 89894    강동구  2021-12-30
# 89895    강동구  2021-12-30
# 89896    강동구  2021-12-30
# 89897    강동구  2021-12-30
# 89898    강동구  2021-12-30
#
# [89899 rows x 14 columns]

# %%
df_20 = pd.read_csv('C:/myPyCode/data/2021_물가/생필품 농수축산물 가격 정보(2020년).csv', encoding = 'cp949')
df_20
# Out:
#            일련번호  시장/마트 번호   시장/마트 이름  품목 번호        품목 이름     실판매규격  가격(원)  \
# 0       1621162         1       통인시장    309   양파(1.5kg망)       1kg   2000
# 1       1628949       228     방배종합시장    277           호박    1개268g   1500
# 2       1626799        51  NC백화점 불광점     18          닭고기  1마리(1kg)   8990
# 3       1630920       223   홈플러스 목동점    278          쇠고기      600g  35982
# 4       1622882         1       통인시장    309   양파(1.5kg망)       1kg   2000
# ...         ...       ...        ...    ...          ...       ...    ...
# 117447  1509343        68  롯데백화점 미아점    306  배(신고, 600g)        1개   4000
# 117448  1509368       206  하나로클럽 미아점     99   돼지고기(생삼겹살)      600g   9300
# 117449  1509346        68  롯데백화점 미아점    309   양파(1.5kg망)     1.5kg   3980
# 117450  1509369       206  하나로클럽 미아점    275      닭고기(중간)       1마리   4670
# 117451  1509347        68  롯데백화점 미아점    310     상추(100g)      100g   1980
#
#            년도-월         비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# 0       2020-12     국내산,무안                  1              전통시장  110000
# 1       2020-12  국내산/인큐베이터                  1              전통시장  650000
# 2       2020-12      올품 토종                  2              대형마트  380000
# 3       2020-12  국내산(음성)농협                  2              대형마트  470000
# 4       2020-12     국내산,무안                  1              전통시장  110000
# ...         ...        ...                ...               ...     ...
# 117447  2020-01        NaN                  2              대형마트  305000
# 117448  2020-01  100g 1550                  2              대형마트  305000
# 117449  2020-01        NaN                  2              대형마트  305000
# 117450  2020-01        NaN                  2              대형마트  305000
# 117451  2020-01        NaN                  2              대형마트  305000
#
#        자치구 이름        점검일자
# 0         종로구  2020-12-21
# 1         서초구  2020-12-21
# 2         은평구  2020-12-21
# 3         양천구  2020-12-21
# 4         종로구  2020-12-21
# ...       ...         ...
# 117447    강북구  2020-01-23
# 117448    강북구  2020-01-23
# 117449    강북구  2020-01-23
# 117450    강북구  2020-01-23
# 117451    강북구  2020-01-23
#
# [117452 rows x 14 columns]

# %% [markdown]
# # 데이터 전처리 시작

# %%
df_one = pd.merge(df_19, df_20, how = 'outer')

# %%
df_two = pd.merge(df_one, df_21, how = 'outer')

# %%
df = df_two
df
# Out:
#            일련번호  시장/마트 번호  시장/마트 이름  품목 번호        품목 이름      실판매규격  가격(원)  \
# 0       1496335       116  홈플러스 시흥점    311      오이(다다기)         1개   1190
# 1       1499702       115      남문시장    202   돼지고기(생삼겹살)  1등급(600g)  12500
# 2       1503366       115      남문시장    310     상추(100g)         1개    800
# 3       1499701       115      남문시장     58  쇠고기(한우,불고기)  1등급(600g)  23000
# 4       1503365       115      남문시장    309   양파(1.5kg망)         1개   2500
# ...         ...       ...       ...    ...          ...        ...    ...
# 320838  1724775       154  홈플러스 강동점    320      달걀(30개)         특란   6490
# 320839  1724776       154  홈플러스 강동점    144    조기(국산,냉동)        1마리   1190
# 320840  1724777       154  홈플러스 강동점    264   명태(냉동,수입산)        1마리   3490
# 320841  1724778       154  홈플러스 강동점    256   오징어(냉동,국산)        1마리   4980
# 320842  1724779       154  홈플러스 강동점    266   고등어(생물,국산)        1마리   3990
#
#            년도-월          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# 0       2019-12          국산                  2              대형마트  545000
# 1       2019-12          국산                  1              전통시장  545000
# 2       2019-12          국산                  1              전통시장  545000
# 3       2019-12          국산                  1              전통시장  545000
# 4       2019-12          국산                  1              전통시장  545000
# ...         ...         ...                ...               ...     ...
# 320838  2021-12         국내산                  2              대형마트  740000
# 320839  2021-12  국내산3마리3570                  2              대형마트  740000
# 320840  2021-12    수입산(러시아)                  2              대형마트  740000
# 320841  2021-12         국내산                  2              대형마트  740000
# 320842  2021-12  국내산2마리7980                  2              대형마트  740000
#
#        자치구 이름        점검일자
# 0         금천구  2019-12-30
# 1         금천구  2019-12-30
# 2         금천구  2019-12-30
# 3         금천구  2019-12-30
# 4         금천구  2019-12-30
# ...       ...         ...
# 320838    강동구  2021-12-30
# 320839    강동구  2021-12-30
# 320840    강동구  2021-12-30
# 320841    강동구  2021-12-30
# 320842    강동구  2021-12-30
#
# [320843 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320843 entries, 0 to 320842
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   일련번호               320843 non-null  int64
#  1   시장/마트 번호           320843 non-null  int64
#  2   시장/마트 이름           320843 non-null  object
#  3   품목 번호              320843 non-null  int64
#  4   품목 이름              320787 non-null  object
#  5   실판매규격              320843 non-null  object
#  6   가격(원)              320843 non-null  int64
#  7   년도-월               320843 non-null  object
#  8   비고                 253682 non-null  object
#  9   시장유형 구분(시장/마트) 코드  320843 non-null  int64
#  10  시장유형 구분(시장/마트) 이름  320843 non-null  object
#  11  자치구 코드             320843 non-null  int64
#  12  자치구 이름             320843 non-null  object
#  13  점검일자               320843 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 36.7+ MB

# %%
df.describe()
# Out:
#                일련번호       시장/마트 번호          품목 번호         가격(원)  \
# count  3.208430e+05  320843.000000  320843.000000  3.208430e+05
# mean   1.556445e+06     103.142671     212.581568  1.346572e+04
# std    9.823942e+04      68.695718     109.217373  4.227410e+06
# min    1.357080e+06       1.000000      13.000000  0.000000e+00
# 25%    1.473784e+06      44.000000     119.000000  2.000000e+03
# 50%    1.560484e+06      92.000000     265.000000  3.450000e+03
# 75%    1.641340e+06     146.000000     307.000000  5.950000e+03
# max    1.724779e+06     229.000000     324.000000  2.394024e+09
#
#        시장유형 구분(시장/마트) 코드         자치구 코드
# count      320843.000000  320843.000000
# mean            1.510072  415991.341560
# std             0.499899  185545.761174
# min             1.000000  110000.000000
# 25%             1.000000  260000.000000
# 50%             2.000000  410000.000000
# 75%             2.000000  560000.000000
# max             2.000000  740000.000000

# %%
# 아래부터 시장유형 구분 이름, 자치구 이름, 품목 이름, 시장/마트 이름을 남기기 위해
# 딕셔너리 제작 시작
mart_name = df['시장유형 구분(시장/마트) 코드']
mart_code = df['시장유형 구분(시장/마트) 이름']
mart = {}
for i in range(len(mart_code)):
      mart[mart_code[i]] = mart_name[i]
print(mart)
# Out:
# {'대형마트': 2, '전통시장': 1}

# %%
region_name = df['자치구 이름']
region_code = df['자치구 코드']
region = {}
for i in range(len(region_code)):
      region[region_code[i]] = region_name[i]
print(region)
# Out:
# {545000: '금천구', 680000: '강남구', 560000: '영등포구', 740000: '강동구', 410000: '서대문구', 230000: '동대문구', 500000: '강서구', 440000: '마포구', 140000: '중구', 305000: '강북구', 710000: '송파구', 260000: '중랑구', 215000: '광진구', 320000: '도봉구', 590000: '동작구', 170000: '용산구', 470000: '양천구', 290000: '성북구', 650000: '서초구', 530000: '구로구', 620000: '관악구', 350000: '노원구', 110000: '종로구', 200000: '성동구', 380000: '은평구'}

# %%
cat_name = df['품목 이름']
cat_code = df['품목 번호']
cat = {}
for i in range(len(cat_code)):
      cat[cat_code[i]] = cat_name[i]
print(cat)
# Out:
# {311: '오이(다다기)', 202: '돼지고기(생삼겹살)', 310: '상추(100g)', 58: '쇠고기(한우,불고기)', 309: '양파(1.5kg망)', 119: '호박(인큐베이터)', 260: '조기(냉동,수입산)', 283: '닭고기(육계)', 171: '달걀(10개)', 320: '달걀(30개)', 136: '조기(국산,생물)', 264: '명태(냉동,수입산)', 318: '고등어(30cm,수입산)', 305: '사과(부사, 300g)', 254: '오징어(생물,국산)', 266: '고등어(생물,국산)', 152: '명태(러시아,냉동)', 306: '배(신고, 600g)', 308: '무(1kg)', 307: '배추(2.5~3kg)', 312: '애호박', 144: '조기(국산,냉동)', 268: '고등어(냉동,국산)', 248: '배(신고),중급(대)', 125: '배추(국산)', 26: '배추', 24: '양파', 25: '무', 276: '배(신고)', 303: '조기', 288: '동태', 23: '상추', 256: '오징어(냉동,국산)', 13: '고등어', 27: '배', 257: '오징어(냉동,수입산)', 52: '돼지고기(삼겹살)', 18: '닭고기', 285: '돼지고기', 131: nan, 50: '사과(부사)', 277: '호박', 138: '닭고기(토종닭)', 99: '돼지고기(생삼겹살)', 244: '사과(부사),중급(대)', 269: '고등어(냉동,수입산)', 259: '조기(냉동,국산)', 271: '배추(중간)', 284: '배(중품)', 22: '오이', 304: '고등어', 314: '냉동참조기(20cm,국산)', 265: '명태(생물,수입산)', 253: '오징어', 302: '명태', 17: '달걀', 278: '쇠고기', 282: '무(세척무)', 175: '배추(중간)', 274: '무(세척무, 중)', 261: '조기(생물,수입산)', 316: '고등어(30cm,국산)', 118: '호박(인큐베이터),중간', 133: '무(세척무)', 258: '조기(생물,국산)', 275: '닭고기(중간)', 255: '오징어(생물,수입산)', 28: '사과', 135: '조기(중국산,생물)', 272: '양파(작은망)', 315: '명태(45cm,수입산)', 181: '달걀(왕란)', 262: '명태(생물,국산)', 106: '쇠고기(한우2등급)', 267: '고등어(생물,수입산)', 321: '달걀(15개)', 134: '달걀(왕란)', 270: '사과(부사),중급(중)', 82: '쇠고기(육우,불고기)', 263: '명태(냉동,국산)', 279: '사과(중품)', 170: '배(신고),중급(대)', 237: '사과(부사),중급(대)', 51: '배(신고),중급(중)', 54: '오징어(냉동)', 281: '배(중품),신고', 299: '삼겹살', 313: '냉동참조기(20cm,수입)', 184: '명태(일본산,냉동)', 201: '쇠고기(등심)', 129: '쇠고기(육우1등급)', 324: '쌀', 176: '달걀(중란)'}

# %%
market_name = df['시장/마트 이름']
market_code = df['시장/마트 번호']
market = {}
for i in range(len(market_code)):
      market[market_code[i]] = market_name[i]
print(market)
# Out:
# {116: '홈플러스 시흥점', 115: '남문시장', 114: '현대시장', 222: '홈플러스 독산점', 44: '이마트 역삼점', 130: '롯데백화점 영등포점', 154: '홈플러스 강동점', 31: '인왕시장', 88: '롯데백화점 청량리점', 45: '롯데백화점 강남점', 213: '화곡본동시장', 123: '홈플러스 월드컵점', 8: '롯데마트 서울역점', 66: '수유재래시장', 153: '이마트 명일점', 147: '롯데백화점 잠실점', 91: '동원시장', 40: '홈플러스 등촌점', 80: '이마트 자양점', 27: '이마트 창동점', 127: '남성시장', 10: '용문시장', 102: '목3동시장', 214: '이마트 목동점', 90: '우림시장', 13: '돈암제일시장', 217: '방림시장', 120: '망원시장', 151: '암사종합시장', 28: '홈플러스 방학점', 22: '이마트 여의도점', 19: '대림중앙시장', 56: '롯데백화점', 218: '신세계백화점 강남점', 108: '남구로시장', 140: '하나로클럽 양재점', 133: '원당종합시장', 25: '방학동도깨비시장', 33: '현대백화점 신촌점', 11: '남대문시장', 103: '신영시장', 96: '공릉동 도깨비시장', 82: '롯데마트 강변점', 32: '영천시장', 148: '홈플러스 잠실점', 1: '통인시장', 26: '신창시장', 2: '신세계백화점', 129: '태평백화점', 206: '하나로클럽 미아점', 15: '이마트 미아점', 136: '세이브 마트', 94: '홈플러스 면목점', 60: '이마트 청계점', 20: '영등포전통시장', 216: '도곡시장', 145: '마천중앙시장', 134: '신원시장(신림1동)', 21: '홈플러스 영등포점', 207: '관악신사시장(신림4동)', 215: '청담삼익시장', 74: '이마트 왕십리점', 38: '송화시장', 200: '뉴코아아울렛 강남점', 14: '장위골목시장', 6: '이마트 용산점', 210: '상계중앙시장', 62: '후암시장', 16: '현대백화점 미아점', 110: '이마트 신도림점', 212: '노룬산골목시장', 135: '롯데백화점 관악점', 84: '청량리종합시장', 51: 'NC백화점 불광점', 146: '방이시장', 72: '금남시장', 63: '농협 하나로마트 용산점', 78: '자양골목시장', 199: '서울중앙시장', 121: '마포농수산물시장', 42: '이마트 가양점', 85: '경동시장', 92: '이마트 상봉점', 68: '롯데백화점 미아점', 49: '대림시장', 205: '둔촌역전통시장', 100: '홈플러스 중계점', 75: '이마트 성수점', 86: '홈플러스 동대문점', 55: '광장시장', 109: '고척근린시장', 98: '롯데백화점 노원점', 53: '이마트 은평점', 73: '뚝도시장', 224: '농협하나로마트 신촌점', 221: '숭인시장', 223: '홈플러스 목동점', 226: '롯데마트 구로점', 220: '롯데슈퍼', 219: '대조시장', 112: '애경백화점', 225: '이마트 에브리데이 창동점', 202: '구로시장', 228: '방배종합시장', 227: 'NC백화점 신구로점', 229: '이마트 이수점'}

# %% [markdown]
# ## 필요 데이터 확인

# %%
# 필요 데이터 확인
# df.iloc[:,0:6].sort_values(by='자치구 이름')

# %%
df['가격(원)'].value_counts().head(20) # 가격이 0원인 행 삭제 예정
# Out:
# 3000    15383
# 2000    13706
# 2500    12974
# 4000    12420
# 5000    10549
# 1000     9691
# 3500     8389
# 1500     8247
# 6000     6038
# 2980     4436
# 4500     4094
# 500      3911
# 3980     3812
# 0        3694
# 1980     3678
# 6500     3211
# 5500     3188
# 4980     3097
# 2990     2684
# 3990     2586
# Name: 가격(원), dtype: int64

# %%
df['품목 이름'].isnull().sum() # 결측치 확인
# Out:
# 56

# %%
# 가격이 0원인 행 sort시켜서 다시 선언
df = df.sort_values(by='가격(원)')
df
# Out:
#            일련번호  시장/마트 번호   시장/마트 이름  품목 번호        품목 이름     실판매규격  \
# 234816  1635144       147  롯데백화점 잠실점    302           명태       1마리
# 222105  1511343       154   홈플러스 강동점    264   명태(냉동,수입산)       1마리
# 180372  1564232        44    이마트 역삼점    288           동태       1마리
# 111459  1369939       129      태평백화점    152   명태(러시아,냉동)       1마리
# 180353  1568989        44    이마트 역삼점    288           동태       1마리
# ...         ...       ...        ...    ...          ...       ...
# 148594  1602645        10       용문시장    256   오징어(냉동,국산)  1마리 45cm
# 25965   1488498        94   홈플러스 면목점    306  배(신고, 600g)        1개
# 139423  1601540       223   홈플러스 목동점    288           동태       1마리
# 127610  1613426       214    이마트 목동점     13          고등어       1마리
# 286834  1688423        56      롯데백화점     99   돼지고기(생삼겹살)      600g
#
#              가격(원)     년도-월         비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  \
# 234816           0  2021-01        NaN                  2              대형마트
# 222105           0  2020-01       입고안됨                  2              대형마트
# 180372           0  2020-07       입고안됨                  2              대형마트
# 111459           0  2019-02         없음                  2              대형마트
# 180353           0  2020-07       입고안됨                  2              대형마트
# ...            ...      ...        ...                ...               ...
# 148594      310000  2020-10     국내산 냉동                  1              전통시장
# 25965       403890  2019-11        국내산                  2              대형마트
# 139423    34902990  2020-10   수입산(러시아)                  2              대형마트
# 127610    35002980  2020-11     국내산,생물                  2              대형마트
# 286834  2394023940  2021-08  국내산,돈육삼겹살                  2              대형마트
#
#         자치구 코드 자치구 이름        점검일자
# 234816  710000    송파구  2021-01-28
# 222105  740000    강동구  2020-01-30
# 180372  680000    강남구  2020-07-30
# 111459  590000    동작구  2019-02-28
# 180353  680000    강남구  2020-07-30
# ...        ...    ...         ...
# 148594  170000    용산구  2020-10-29
# 25965   260000    중랑구  2019-11-28
# 139423  470000    양천구  2020-10-29
# 127610  470000    양천구  2020-11-30
# 286834  140000     중구  2021-08-26
#
# [320843 rows x 14 columns]

# %%
# 가격이 0원인 상품, 1원인 상품 iloc로 삭제
df = df.iloc[3695:,:]
df
# Out:
#            일련번호  시장/마트 번호  시장/마트 이름  품목 번호        품목 이름      실판매규격  \
# 70063   1424146       213    화곡본동시장    119    호박(인큐베이터)         1개
# 261572  1661675       214   이마트 목동점    312          애호박         1개
# 243730  1643905       102     목3동시장     25            무  1개(1.8kg)
# 65247   1447285       146      방이시장    310     상추(100g)       100g
# 87660   1419371       114      현대시장    311      오이(다다기)         1개
# ...         ...       ...       ...    ...          ...        ...
# 148594  1602645        10      용문시장    256   오징어(냉동,국산)   1마리 45cm
# 25965   1488498        94  홈플러스 면목점    306  배(신고, 600g)         1개
# 139423  1601540       223  홈플러스 목동점    288           동태        1마리
# 127610  1613426       214   이마트 목동점     13          고등어        1마리
# 286834  1688423        56     롯데백화점     99   돼지고기(생삼겹살)       600g
#
#              가격(원)     년도-월         비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  \
# 70063           10  2019-07       청원생명                  1              전통시장
# 261572          90  2021-05  국내산(진주논개)                  2              대형마트
# 243730         100  2021-02        국내산                  1              전통시장
# 65247          100  2019-08        NaN                  1              전통시장
# 87660          100  2019-06         국산                  1              전통시장
# ...            ...      ...        ...                ...               ...
# 148594      310000  2020-10     국내산 냉동                  1              전통시장
# 25965       403890  2019-11        국내산                  2              대형마트
# 139423    34902990  2020-10   수입산(러시아)                  2              대형마트
# 127610    35002980  2020-11     국내산,생물                  2              대형마트
# 286834  2394023940  2021-08  국내산,돈육삼겹살                  2              대형마트
#
#         자치구 코드 자치구 이름        점검일자
# 70063   500000    강서구  2019-07-29
# 261572  470000    양천구  2021-05-27
# 243730  470000    양천구  2021-02-25
# 65247   710000    송파구  2019-08-29
# 87660   545000    금천구  2019-06-27
# ...        ...    ...         ...
# 148594  170000    용산구  2020-10-29
# 25965   260000    중랑구  2019-11-28
# 139423  470000    양천구  2020-10-29
# 127610  470000    양천구  2020-11-30
# 286834  140000     중구  2021-08-26
#
# [317148 rows x 14 columns]

# %%
# 23억, 3500만원, 3490만원어치 상품 삭제 (outlier)
df = df.iloc[:317145]
df
# Out:
#            일련번호  시장/마트 번호      시장/마트 이름  품목 번호        품목 이름          실판매규격  \
# 70063   1424146       213        화곡본동시장    119    호박(인큐베이터)             1개
# 261572  1661675       214       이마트 목동점    312          애호박             1개
# 243730  1643905       102         목3동시장     25            무      1개(1.8kg)
# 65247   1447285       146          방이시장    310     상추(100g)           100g
# 87660   1419371       114          현대시장    311      오이(다다기)             1개
# ...         ...       ...           ...    ...          ...            ...
# 244208  1644451        45     롯데백화점 강남점     50       사과(부사)     1봉(1.08kg)
# 179632  1575337        40      홈플러스 등촌점     58  쇠고기(한우,불고기)     600g(1+등급)
# 92710   1408770        63  농협 하나로마트 용산점     58  쇠고기(한우,불고기)  1근 6200g (1+)
# 148594  1602645        10          용문시장    256   오징어(냉동,국산)       1마리 45cm
# 25965   1488498        94      홈플러스 면목점    306  배(신고, 600g)             1개
#
#          가격(원)     년도-월            비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  \
# 70063       10  2019-07          청원생명                  1              전통시장
# 261572      90  2021-05     국내산(진주논개)                  2              대형마트
# 243730     100  2021-02           국내산                  1              전통시장
# 65247      100  2019-08           NaN                  1              전통시장
# 87660      100  2019-06            국산                  1              전통시장
# ...        ...      ...           ...                ...               ...
# 244208  210000  2021-02       국내산 3개입                  2              대형마트
# 179632  260520  2020-07  음성농협(설도)전단상품                  2              대형마트
# 92710   288200  2019-05    100g 47820                  2              대형마트
# 148594  310000  2020-10        국내산 냉동                  1              전통시장
# 25965   403890  2019-11           국내산                  2              대형마트
#
#         자치구 코드 자치구 이름        점검일자
# 70063   500000    강서구  2019-07-29
# 261572  470000    양천구  2021-05-27
# 243730  470000    양천구  2021-02-25
# 65247   710000    송파구  2019-08-29
# 87660   545000    금천구  2019-06-27
# ...        ...    ...         ...
# 244208  680000    강남구  2021-02-25
# 179632  500000    강서구  2020-07-30
# 92710   170000    용산구  2019-05-30
# 148594  170000    용산구  2020-10-29
# 25965   260000    중랑구  2019-11-28
#
# [317145 rows x 14 columns]

# %%
# 각종 지표들을 확인합니다

# %% [markdown]
# ## 추가적인 인사이트

# %%
# 자치구 - 가격별로 시각화 
plt.figure(figsize = (13,9))
sns.lineplot(data = df, x='자치구 이름', y = '가격(원)')
plt.show()
# 어떤 자치구가 높은 가격대로 형성되어 있을까요?

# %%
# 품목 - 가격별로 시각화 
plt.figure(figsize = (13,4))
sns.barplot(data = df.tail(10), x='품목 이름', y = '가격(원)')
plt.show()

# 어떤 상품들이 높은 가격대로 형성되어 있을까요?

# %%
plt.figure(figsize = (13,9))
sns.barplot(data = df.tail(10), x = '시장/마트 이름', y = '가격(원)', palette='rainbow')
plt.show()
# 어떤 마트가 가장 높은 가격대를 갖고 있을까요?

# %%
plt.figure(figsize = (13,9))
sns.barplot(data = df, x = '시장유형 구분(시장/마트) 이름', y = '가격(원)', palette='rainbow')
plt.show()
# 전통시장 vs 마트, 어떤 곳이 더 높은 가격이 형성되어 있을까요?

# %%
# 자치구 - 시장/마트 갯수
plt.figure(figsize = (13,9))
sns.barplot(data = df.tail(100), x = '자치구 이름', y = '시장/마트 번호', palette='rainbow')
plt.show()

# 어떤 자치구가 가장 많은 시장/마트를 포함하고 있을까요?

# %%
# 연도 - 가격- 시장/마트 유형 구분별로 시각화
plt.figure(figsize = (13,9))
sns.lineplot(data = df, x='년도-월', y = '가격(원)', hue = '시장유형 구분(시장/마트) 이름')
plt.show()

# 연도별로 가격이 구분되는 추이(시장 vs 대형마트)

# %%
# 아래부터 필요없는 행 제거 예정
# 주의
df.drop(['시장유형 구분(시장/마트) 이름','시장유형 구분(시장/마트) 코드'], axis = 1, inplace = True)

# %%
df.drop(['시장/마트 이름', '자치구 이름'],axis=1, inplace = True)

# %%
df.drop(['점검일자','실판매규격','품목 이름','비고','일련번호'], axis = 1, inplace = True)

# %%
# df.drop(['자치구 이름'],axis=1, inplace = True) # 실수

# %%
df # drop된 내용 확인
# Out:
#         시장/마트 번호  품목 번호   가격(원)  년도-월  자치구 코드
# 70063        213    119      10  2019  500000
# 261572       214    312      90  2021  470000
# 243730       102     25     100  2021  470000
# 65247        146    310     100  2019  710000
# 87660        114    311     100  2019  545000
# ...          ...    ...     ...   ...     ...
# 244208        45     50  210000  2021  680000
# 179632        40     58  260520  2020  500000
# 92710         63     58  288200  2019  170000
# 148594        10    256  310000  2020  170000
# 25965         94    306  403890  2019  260000
#
# [317145 rows x 5 columns]

# %%
df['가격(원)'].value_counts().head(20)
# Out:
# 3000    15383
# 2000    13706
# 2500    12974
# 4000    12420
# 5000    10549
# 1000     9691
# 3500     8389
# 1500     8247
# 6000     6038
# 2980     4436
# 4500     4094
# 500      3911
# 3980     3812
# 1980     3678
# 6500     3211
# 5500     3188
# 4980     3097
# 2990     2684
# 3990     2586
# 5980     2507
# Name: 가격(원), dtype: int64

# %%
# 가격이 0원인 행 sort시켜서 다시 선언
df = df.sort_values(by='가격(원)')
df
# Out:
#         시장/마트 번호  품목 번호   가격(원)  년도-월  자치구 코드
# 70063        213    119      10  2019  500000
# 261572       214    312      90  2021  470000
# 34530        205    310     100  2019  740000
# 244482       102     25     100  2021  470000
# 64851        145    119     100  2019  710000
# ...          ...    ...     ...   ...     ...
# 244208        45     50  210000  2021  680000
# 179632        40     58  260520  2020  500000
# 92710         63     58  288200  2019  170000
# 148594        10    256  310000  2020  170000
# 25965         94    306  403890  2019  260000
#
# [317145 rows x 5 columns]

# %%
# # 년도-월을 전부 월별로 바꾸기
# df['년도-월'] = pd.to_datetime(df['년도-월'])
# df['년도-월'] = df['년도-월'].dt.month

# %%
# df.sort_values(by = '년도-월')

# %%
# # 년도-월을 전부 연도별로 바꾸기
# df['년도-월'] = pd.to_datetime(df['년도-월'])
# df['년도-월'] = df['년도-월'].dt.year

# %%
df
# Out:
#         시장/마트 번호  품목 번호   가격(원)  년도-월  자치구 코드
# 70063        213    119      10  2019  500000
# 261572       214    312      90  2021  470000
# 34530        205    310     100  2019  740000
# 244482       102     25     100  2021  470000
# 64851        145    119     100  2019  710000
# ...          ...    ...     ...   ...     ...
# 244208        45     50  210000  2021  680000
# 179632        40     58  260520  2020  500000
# 92710         63     58  288200  2019  170000
# 148594        10    256  310000  2020  170000
# 25965         94    306  403890  2019  260000
#
# [317145 rows x 5 columns]

# %%
df.isnull().sum() # 결측치 확인
# Out:
# 시장/마트 번호    0
# 품목 번호       0
# 가격(원)       0
# 년도-월        0
# 자치구 코드      0
# 자치구 이름      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317145 entries, 70063 to 25965
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   시장/마트 번호  317145 non-null  int64
#  1   품목 번호     317145 non-null  int64
#  2   가격(원)     317145 non-null  int64
#  3   년도-월      317145 non-null  int64
#  4   자치구 코드    317145 non-null  int64
#  5   자치구 이름    317145 non-null  object
# dtypes: int64(5), object(1)
# memory usage: 25.0+ MB

# %%
df.sort_values(by = '년도-월').tail(20)
# Out:
#         시장/마트 번호  품목 번호   가격(원)  년도-월  자치구 코드 자치구 이름
# 229161       103    276    2500  1970  470000    양천구
# 3061         127    171    2500  1970  590000    동작구
# 171478       120    152    2500  1970  440000    마포구
# 27663        120     23    2500  1970  440000    마포구
# 146069       219     24    2500  1970  380000    은평구
# 86098         19     13    2500  1970  560000   영등포구
# 295041       109    303    2500  1970  530000    구로구
# 146075       219     27    2500  1970  380000    은평구
# 298613       133    260    2500  1970  620000    관악구
# 106751       103    276    2500  1970  470000    양천구
# 298603       133    308    2500  1970  620000    관악구
# 302985       109    266    2500  1970  530000    구로구
# 171506       134    254    2500  1970  620000    관악구
# 247544       145    305    2500  1970  710000    송파구
# 85503         32    264    2500  1970  410000   서대문구
# 171508       134    306    2500  1970  620000    관악구
# 165658       221    308    2500  1970  305000    강북구
# 94247         49    309    2500  1970  380000    은평구
# 79695         62    171    2500  1970  170000    용산구
# 25965         94    306  403890  1970  260000    중랑구

# %%
# df.replace('-', inplace = True)

# %%
# 특수문자 삭제
# df["년도-월"] = df["년도-월"].str.replace(pat=r'[^\w]', repl=r'', regex=True)
# df['년도-월'] = df['년도-월'].astype('int')

# %%
df
# Out:
#         시장/마트 번호  품목 번호   가격(원)  년도-월  자치구 코드
# 70063        213    119      10  2019  500000
# 261572       214    312      90  2021  470000
# 34530        205    310     100  2019  740000
# 244482       102     25     100  2021  470000
# 64851        145    119     100  2019  710000
# ...          ...    ...     ...   ...     ...
# 244208        45     50  210000  2021  680000
# 179632        40     58  260520  2020  500000
# 92710         63     58  288200  2019  170000
# 148594        10    256  310000  2020  170000
# 25965         94    306  403890  2019  260000
#
# [317145 rows x 5 columns]

# %%
df['년도-월'].value_counts()
# Out:
# 2020    116137
# 2019    112145
# 2021     88863
# Name: 년도-월, dtype: int64

# %% [markdown]
# ## 전처리 종료. 시각화

# %%
# 자치구 코드 - 가격별로 시각화 
plt.figure(figsize = (13,9))
sns.lineplot(data = df, x='자치구 코드', y = '가격(원)')
plt.show()

# %%
# 품목 - 가격별로 시각화 
plt.figure(figsize = (13,4))
sns.barplot(data = df.tail(10), x='품목 번호', y = '가격(원)')
plt.show()

# %%
df.columns
# Out:
# Index(['시장/마트 번호', '품목 번호', '가격(원)', '년도-월', '자치구 코드'], dtype='object')

# %%
df_new = df.rename(columns={'년도-월': '년'})
df_new
# Out:
#         시장/마트 번호  품목 번호   가격(원)     년  자치구 코드 자치구 이름
# 70063        213    119      10  1970  500000    강서구
# 261572       214    312      90  1970  470000    양천구
# 34530        205    310     100  1970  740000    강동구
# 244482       102     25     100  1970  470000    양천구
# 64851        145    119     100  1970  710000    송파구
# ...          ...    ...     ...   ...     ...    ...
# 244208        45     50  210000  1970  680000    강남구
# 179632        40     58  260520  1970  500000    강서구
# 92710         63     58  288200  1970  170000    용산구
# 148594        10    256  310000  1970  170000    용산구
# 25965         94    306  403890  1970  260000    중랑구
#
# [317145 rows x 6 columns]

# %%
# X,y 를 다르게 구분해서 훈련 시작

X = df.drop('가격(원)', axis = 1)
y = df['가격(원)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %% [markdown]
# # 선형회귀 모델 시작

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([6881.99779365, 4844.49591765, 3705.79777136, ..., 3982.46544955,
#        4584.29962765, 3629.85783588])

# %% [markdown]
# ## 결정계수 평가

# %%
mean_squared_error(y_test, pred)
# Out:
# 52885519.83597086

# %%
# rmse
mean_squared_error(y_test, pred) ** 0.5
# Out:
# 7272.243108970633

# %%
model.score(X_train, y_train) # R²
# Out:
# 0.0727616965554323

# %%
model.coef_
# Out:
# array([-7.47285303e-01, -1.84398670e+01,  3.38018798e+02,  6.24293054e-04])

# %%
comparison = pd.DataFrame({
    'actual': y_test, # 실제값
    'pred': pred
}) 
comparison
# Out:
#         actual         pred
# 286853    6980  6881.997794
# 161165    6000  4844.495918
# 29770     5480  3705.797771
# 95177     3000  3860.782983
# 135067    5933  9206.979337
# ...        ...          ...
# 221152    2990  4148.287564
# 296266    2000  4416.592734
# 154795    5980  3982.465450
# 100085    4990  4584.299628
# 39302     3580  3629.857836
#
# [63429 rows x 2 columns]

# %% [markdown]
# ## 시각화 시작

# %%
# 산점도
plt.figure(figsize=(20, 12))
sns.scatterplot(x = 'actual', y= 'pred', data = comparison)
plt.show()

# %%
plt.figure(figsize=(20, 12))
sns.regplot(x = 'actual', y= 'pred', data = comparison)
plt.show()

# %% [markdown]
# # 결정트리 모델

# %%
# 모델 설정
model = DecisionTreeRegressor(random_state=10, max_depth = 500)

# %%
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
pred
# Out:
# array([7429.13043478, 5415.09433962, 3396.48148148, ..., 5769.81132075,
#        4585.        , 2287.54716981])

# %%
# mse 평가
mean_squared_error(y_test, pred)
# Out:
# 4745971.50434268

# %%
# rmse 평가
mean_squared_error(y_test, pred, squared=False)
# Out:
# 2178.5250754450085

# %%
# mae 평가

mean_absolute_error(y_test, pred)
# Out:
# 910.0346657466318

# %%
model.score(X_train, y_train) # R²
# 0.89점
# Out:
# 0.8906056519778784

# %%
plt.figure(figsize=(20, 10)) # 그래프 크기 설정
plot_tree(model, max_depth=10, fontsize=20)
plt.show() # 로딩시간 다수에 주의 (10분)

# %% [markdown]
# # 로지스틱 회귀

# %%
# 로지스틱 회귀 사용

# %%time
model = LogisticRegression()

model.fit(X_train, y_train)
pred = model.predict(X_test)
# RAM 고장에 주의

# %%
# probability
pred_proba = model.predict_proba(X_test)
pred_proba

# %%
# mse -> 실제값, 예측값
mean_squared_error(y_test, pred)

# %%
# rmse
mean_squared_error(y_test, pred, squared=False)

# %% [markdown]
# ## 결정계수 점수

# %%
# 학습시킨 독립변수, 종속변수
model.score(X_train, y_train) # R²
# Out:
# 0.8906056519778784

# %% [markdown]
# # Ridge regression

# %%
# Ridge회귀 시작
# rmse 구함
ridge = Ridge(alpha = 10)

neg_mse_scores = cross_val_score(ridge, X, y, scoring='neg_mean_squared_error', cv = 9) # cv 추후 변경
neg_mse_scores
# Out:
# array([-3.60691540e+07, -3.07632483e+07, -2.20129430e+07, -1.49548748e+07,
#        -9.47155931e+06, -6.15255294e+06, -4.38976225e+06, -1.40317880e+07,
#        -5.25806749e+08])

# %%
rmse_scores = np.sqrt(-1*neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse
# Out:
# 6048.972270778937

# %%
print('개별 negative mse scores:', np.round(neg_mse_scores),
      '\n개별 rmse scores:', np.round(rmse_scores,3), '\n평균 RMSE: {0:.3F}'.format(avg_rmse) )
# Out:
# 개별 negative mse scores: [-3.60691540e+07 -3.07632480e+07 -2.20129430e+07 -1.49548750e+07
#  -9.47155900e+06 -6.15255300e+06 -4.38976200e+06 -1.40317880e+07
#  -5.25806749e+08]
# 개별 rmse scores: [ 6005.76   5546.463  4691.795  3867.153  3077.59   2480.434  2095.176
#   3745.903 22930.476]
# 평균 RMSE: 6048.972

# %%
alphas = [1, 10, 50, 100]
for alpha in alphas :
   ridge = Ridge(alpha = alpha)

   neg_mse_scores = cross_val_score(ridge, X, y, scoring='neg_mean_squared_error', cv = 9)
   avg_rmse = np.mean(np.sqrt(-1*neg_mse_scores))
   print('alpha {0}일때 9fold의 평균 rmse: {1:.3f}'.format(alpha, avg_rmse))
# Out:
# alpha 1일때 9fold의 평균 rmse: 6048.973
# alpha 10일때 9fold의 평균 rmse: 6048.972
# alpha 50일때 9fold의 평균 rmse: 6048.968
# alpha 100일때 9fold의 평균 rmse: 6048.962

# %% [markdown]
# ## RMSE와 시각화

# %%
# alpha (0~100)에 따른 피처별 회귀 계수를 데이터프레임으로 표시

fig, axs = plt.subplots(figsize=(18,10), nrows=1, ncols=4)
coeff_df = pd.DataFrame()

for pos, alpha in enumerate(alphas):
   ridge = Ridge(alpha = alpha)
   ridge.fit(X, y)
   coeff = pd.Series(data=ridge.coef_, index = X.columns)
   colname = 'alpha:'+str(alpha)
   coeff_df[colname]=coeff

   coeff = coeff.sort_values(ascending  =False)
   axs[pos].set_title(colname)
   axs[pos].set_xlim(-3, 6)
   sns.barplot(x=coeff.values, y=coeff.index, ax=axs[pos], palette = 'icefire')

plt.show()

# %%
ridge_alphas = [0, 10, 50, 100]
sort_column = 'alpha:'+str(ridge_alphas[0])
coeff_df
# Out:
#              alpha:1    alpha:10    alpha:50   alpha:100
# 시장/마트 번호   -0.864782   -0.864779   -0.864765   -0.864747
# 품목 번호     -18.469354  -18.469362  -18.469395  -18.469435
# 년도-월      344.881185  344.865541  344.796031  344.709182
# 자치구 코드      0.000649    0.000649    0.000649    0.000649

# %%
ridge.score(X_train, y_train)
# Out:
# 0.07275983743143855

# %% [markdown]
# # LightGBM 회귀

# %%
#LightGBM 시도

# # 사용할 params정의
params = {"n_estimators" : [100, 500, 1000],"learning_rate" : [0.01, 0.05, 0.1, 0.3]
          ,"lambda_l1" : [0, 10, 20],"lambda_l2" : [0, 10, 20],"max_depth" : [5, 10, 15, 20],"subsample": [0.6, 0.8, 1]}

# %%
model = LGBMRegressor(random_state = 100)
new_model = RandomizedSearchCV(model,
      param_distributions = params, 
      cv = 9,
      random_state=100, n_jobs = -1)

# %%
new_model.fit(X_train, y_train) # 시간 소요 체크
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RandomizedSearchCV(cv=9, estimator=LGBMRegressor(random_state=100), n_jobs=-1,
#                    param_distributions={'lambda_l1': [0, 10, 20],
#                                         'lambda_l2': [0, 10, 20],
#                                         'learning_rate': [0.01, 0.05, 0.1, 0.3],
#                                         'max_depth': [5, 10, 15, 20],
#                                         'n_estimators': [100, 500, 1000],
#                                         'subsample': [0.6, 0.8, 1]},
#                    random_state=100)

# %% [markdown]
# ## 결정계수 점수

# %%
new_model.best_score_ # 최적의 점수계산
# Out:
# 0.8681272044157713

# %%
new_model.best_params_
# Out:
# {'subsample': 0.8,
#  'n_estimators': 1000,
#  'max_depth': 5,
#  'learning_rate': 0.1,
#  'lambda_l2': 0,
#  'lambda_l1': 0}

# %%
cv_result = pd.DataFrame(new_model.cv_results_)
cv_result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.017921      0.169432         0.288176        0.030013
# 1      28.007245      2.259584         6.762173        0.896030
# 2      24.492097      2.702006         5.387767        1.545537
# 3      21.523842      2.057874         4.704290        0.569973
# 4       3.476124      0.451347         0.301402        0.036406
# 5       4.057838      0.693986         0.229167        0.056001
# 6      16.394566      0.959456         2.233182        0.272518
# 7       3.553037      0.690733         0.330078        0.136035
# 8       3.339980      0.463820         0.311738        0.058094
# 9      10.984048      0.571270         1.647039        0.256614
#
#   param_subsample param_n_estimators param_max_depth param_learning_rate  \
# 0             0.6                100               5                 0.1
# 1             0.8               1000               5                 0.1
# 2               1               1000              15                0.05
# 3               1               1000              10                0.05
# 4             0.8                100              10                 0.1
# 5             0.8                100               5                0.01
# 6               1                500              20                0.01
# 7             0.8                100              20                 0.3
# 8             0.8                100              20                 0.1
# 9             0.6                500              10                0.05
#
#   param_lambda_l2 param_lambda_l1  ... split2_test_score  split3_test_score  \
# 0              20              10  ...          0.845427           0.851957
# 1               0               0  ...          0.887037           0.888862
# 2              20               0  ...          0.885489           0.887878
# 3               0               0  ...          0.886392           0.888820
# 4              20              10  ...          0.861654           0.865677
# 5              10              20  ...          0.687401           0.690379
# 6              20              10  ...          0.845560           0.849927
# 7              10               0  ...          0.881781           0.884997
# 8              20              20  ...          0.864548           0.867878
# 9               0              20  ...          0.879126           0.881145
#
#    split4_test_score  split5_test_score  split6_test_score  split7_test_score  \
# 0           0.785216           0.800657           0.786604           0.849835
# 1           0.820199           0.840730           0.822515           0.887386
# 2           0.820168           0.839645           0.822964           0.886451
# 3           0.820615           0.840197           0.823779           0.887091
# 4           0.797725           0.816487           0.800217           0.865377
# 5           0.633658           0.641796           0.630205           0.683243
# 6           0.783044           0.800229           0.785709           0.848904
# 7           0.816821           0.834272           0.820093           0.883246
# 8           0.799625           0.818753           0.803183           0.866121
# 9           0.813598           0.833263           0.817339           0.880844
#
#    split8_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.858758         0.830591        0.028709                8
# 1           0.891832         0.868127        0.029148                1
# 2           0.890651         0.867283        0.028664                3
# 3           0.891647         0.868060        0.028773                2
# 4           0.870730         0.844869        0.028979                7
# 5           0.695578         0.669487        0.024840               10
# 6           0.856632         0.829287        0.028642                9
# 7           0.887429         0.863825        0.028832                4
# 8           0.871962         0.847024        0.028776                6
# 9           0.885592         0.861129        0.028710                5
#
# [10 rows x 23 columns]

# %%
pred = new_model.predict(X_test)

# %%
# mse 평가
mean_squared_error(y_test, pred)
# Out:
# 5755554.830311395

# %%
# rmse 평가
mean_squared_error(y_test, pred, squared=False)
# Out:
# 2399.0737442420136

# %%
new_model.score(X_train, y_train)
# Out:
# 0.8730338231771096

# %%
# 테이블로 평가
comparison = pd.DataFrame({
    'actual': y_test, # 실제값
    'pred': pred
}) 
comparison
# Out:
#         actual         pred
# 241395    6980  5996.373106
# 64424     6000  5933.799055
# 214799    5480  6210.553027
# 174404    3000  2788.949033
# 167169    5933  8089.704012
# ...        ...          ...
# 55507     2990  2714.761403
# 139266    2000  2192.385587
# 113362    5980  4828.699760
# 12758     4990  6447.632289
# 106138    3580  5014.326743
#
# [63429 rows x 2 columns]

# %% [markdown]
# ## 시각화

# %%
# regplot 제작
plt.figure(figsize=(10, 7))
sns.regplot(x = 'actual', y= 'pred', data = comparison)
plt.show()

# %% [markdown]
# # RandomForest 회귀

# %%
# 랜덤 포레스트 시작 + Kfold 5개
from sklearn.model_selection import KFold
from sklearn import ensemble
kf = KFold(n_splits = 5)

# %%
kf
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %%
list(kf.split(X))
# Out:
# [(array([ 63429,  63430,  63431, ..., 317142, 317143, 317144]),
#   array([    0,     1,     2, ..., 63426, 63427, 63428])),
#  (array([     0,      1,      2, ..., 317142, 317143, 317144]),
#   array([ 63429,  63430,  63431, ..., 126855, 126856, 126857])),
#  (array([     0,      1,      2, ..., 317142, 317143, 317144]),
#   array([126858, 126859, 126860, ..., 190284, 190285, 190286])),
#  (array([     0,      1,      2, ..., 317142, 317143, 317144]),
#   array([190287, 190288, 190289, ..., 253713, 253714, 253715])),
#  (array([     0,      1,      2, ..., 253713, 253714, 253715]),
#   array([253716, 253717, 253718, ..., 317142, 317143, 317144]))]

# %%
X = df.drop('가격(원)', axis = 1)
y = df['가격(원)']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                     test_size = 0.2,
                                                      random_state = 10)

# %%
list1 = []
list2 = []
nTreeList = range(1, 100, 10)

for i in nTreeList:
    depth = None
    maxFeat = 4 
    model = ensemble.RandomForestRegressor(n_estimators=i,
                    max_depth=depth, max_features=maxFeat,
                    oob_score=False, random_state=11)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    list1.append(mean_squared_error(y_test, pred))
    list2.append(mean_squared_error(y_test, pred, squared = False))
    
print("MSE")
print(list1)
print('RMSE')
print(list2)
# Out:
# MSE
# [5334428.690946911, 4800656.80543549, 4838638.738920654, 4818637.282341971, 4815386.480296213, 4804108.810000638, 4793764.238040956, 4777475.016744278, 4774681.616097125, 4775541.113167785]
# RMSE
# [2309.6382164631136, 2191.0401195403724, 2199.6906007256234, 2195.139467628873, 2194.3988881459572, 2191.827732738282, 2189.466656069682, 2185.743584399661, 2185.1044863111524, 2185.3011493082104]

# %% [markdown]
# ## 결정계수 점수

# %%
model.score(X_train, y_train)
# Out:
# 0.8904342504659382

# %% [markdown]
# ## 시각화

# %%
plt.plot(nTreeList, list2)
plt.xlabel('Number of Trees in Ensemble')
plt.ylabel('Root Mean Squared Error')

plt.xlim(0, 18, 2)
plt.ylim(2000, 2500, 100)

plt.show()

# %%
# 종료
